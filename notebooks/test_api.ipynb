# %% [markdown]
# # 01 - Get Heroes data from OpenDota API

# %% [markdown]
# ## Imports Libraries/Modules

# %%
import requests
import json

# %% [markdown]
# ## URLs

# %%
HEROES_STATS_URL = 'https://api.opendota.com/api/heroStats'

# %% [markdown]
# ## Get data from OpenDota API

# %%
response = requests.get(f"{HEROES_STATS_URL}")

# %%
response
# Out:
# <Response [200]>

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# ## Show data in JSON

# %%
response.json()
# Out:
# [{'id': 1,
#   'name': 'npc_dota_hero_antimage',
#   'localized_name': 'Anti-Mage',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'img': '/apps/dota2/images/dota_react/heroes/antimage.png?',
#   'icon': '/apps/dota2/images/dota_react/heroes/icons/antimage.png?',
#   'base_health': 200,
#   'base_health_regen': 0.25,
#   'base_mana': 75,
#   'base_mana_regen': 0,
#   'base_armor': 0,
#   'base_mr': 25,
#   'base_attack_min': 29,
#   'base_attack_max': 33,
#   'base_str': 21,
#   'base_agi': 24,
#   'base_int': 12,
#   'str_gain': 1.6,
#   'agi_gain': 2.8,
#   'int_gain': 1.8,
#   'attack_range': 150,
#   'projectile_speed': 0,
#   'attack_rate': 1.4,
#   'move_speed': 310,
#   'turn_rate': None,
#   'cm_enabled': True,
#   'legs': 2,
#   'hero_id': 1,
#   'turbo_picks': 357082,
#   'turbo_wins': 181983,
#   'pro_ban': 764,
#   'pro_win': 81,
#   'pro_pick': 148,
#   '1_pick': 32873,
#   '1_win': 15859,
#   '2_pick': 47763,
# ...

# %% [markdown]
# ## Convert JSON Data to Python List of Dictionaries

# %%
heroes = json.loads(response.text)

# %%
type(heroes)
# Out:
# list

# %%
len(heroes) # 123 Heroes
# Out:
# 123

# %%
heroes[:5]
# Out:
# [{'id': 1,
#   'name': 'npc_dota_hero_antimage',
#   'localized_name': 'Anti-Mage',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'img': '/apps/dota2/images/dota_react/heroes/antimage.png?',
#   'icon': '/apps/dota2/images/dota_react/heroes/icons/antimage.png?',
#   'base_health': 200,
#   'base_health_regen': 0.25,
#   'base_mana': 75,
#   'base_mana_regen': 0,
#   'base_armor': 0,
#   'base_mr': 25,
#   'base_attack_min': 29,
#   'base_attack_max': 33,
#   'base_str': 21,
#   'base_agi': 24,
#   'base_int': 12,
#   'str_gain': 1.6,
#   'agi_gain': 2.8,
#   'int_gain': 1.8,
#   'attack_range': 150,
#   'projectile_speed': 0,
#   'attack_rate': 1.4,
#   'move_speed': 310,
#   'turn_rate': None,
#   'cm_enabled': True,
#   'legs': 2,
#   'hero_id': 1,
#   'turbo_picks': 357082,
#   'turbo_wins': 181983,
#   'pro_ban': 764,
#   'pro_win': 81,
#   'pro_pick': 148,
#   '1_pick': 32873,
#   '1_win': 15859,
#   '2_pick': 47763,
# ...

# %%
heroes[0]
# Out:
# {'id': 1,
#  'name': 'npc_dota_hero_antimage',
#  'localized_name': 'Anti-Mage',
#  'primary_attr': 'agi',
#  'attack_type': 'Melee',
#  'roles': ['Carry', 'Escape', 'Nuker'],
#  'img': '/apps/dota2/images/dota_react/heroes/antimage.png?',
#  'icon': '/apps/dota2/images/dota_react/heroes/icons/antimage.png?',
#  'base_health': 200,
#  'base_health_regen': 0.25,
#  'base_mana': 75,
#  'base_mana_regen': 0,
#  'base_armor': 0,
#  'base_mr': 25,
#  'base_attack_min': 29,
#  'base_attack_max': 33,
#  'base_str': 21,
#  'base_agi': 24,
#  'base_int': 12,
#  'str_gain': 1.6,
#  'agi_gain': 2.8,
#  'int_gain': 1.8,
#  'attack_range': 150,
#  'projectile_speed': 0,
#  'attack_rate': 1.4,
#  'move_speed': 310,
#  'turn_rate': None,
#  'cm_enabled': True,
#  'legs': 2,
#  'hero_id': 1,
#  'turbo_picks': 357082,
#  'turbo_wins': 181983,
#  'pro_ban': 764,
#  'pro_win': 81,
#  'pro_pick': 148,
#  '1_pick': 32873,
#  '1_win': 15859,
#  '2_pick': 47763,
#  '2_win': 23086,
#  '3_pick': 49323,
# ...

# %%
print(heroes[0]["id"])
print(heroes[0]["name"])
print(heroes[0]["primary_attr"])
print(heroes[0]["attack_type"])
print(heroes[0]["roles"])
print(heroes[0]["img"])
print(heroes[0]["icon"])
print(heroes[0]["base_health"])
print(heroes[0]["base_health_regen"])
print(heroes[0]["base_mana"])
print(heroes[0]["base_mana_regen"])
print(heroes[0]["base_armor"])
print(heroes[0]["base_mr"])
print(heroes[0]["base_attack_min"])
print(heroes[0]["base_attack_max"])
print(heroes[0]["base_str"])
print(heroes[0]["base_agi"])
print(heroes[0]["base_int"])
print(heroes[0]["str_gain"])
print(heroes[0]["agi_gain"])
print(heroes[0]["int_gain"])
print(heroes[0]["attack_range"])
print(heroes[0]["projectile_speed"])
print(heroes[0]["attack_rate"])
print(heroes[0]["move_speed"])
print(heroes[0]["turn_rate"])
print(heroes[0]["cm_enabled"])
# Out:
# 1
# npc_dota_hero_antimage
# agi
# Melee
# ['Carry', 'Escape', 'Nuker']
# /apps/dota2/images/dota_react/heroes/antimage.png?
# /apps/dota2/images/dota_react/heroes/icons/antimage.png?
# 200
# 0.25
# 75
# 0
# 0
# 25
# 29
# 33
# 21
# 24
# 12
# 1.6
# 2.8
# 1.8
# 150
# 0
# 1.4
# 310
# None
# True

# %% [markdown]
# ## Print all heroes and specific fields

# %%
for hero in range(len(heroes)):
  print(heroes[hero]["id"])
  print(heroes[hero]["name"])
  print(heroes[hero]["primary_attr"])
  print(heroes[hero]["attack_type"])
  print(heroes[hero]["roles"])
  print(heroes[hero]["img"])
  print(heroes[hero]["icon"])
  print(heroes[hero]["base_health"])
  print(heroes[hero]["base_health_regen"])
  print(heroes[hero]["base_mana"])
  print(heroes[hero]["base_mana_regen"])
  print(heroes[hero]["base_armor"])
  print(heroes[hero]["base_mr"])
  print(heroes[hero]["base_attack_min"])
  print(heroes[hero]["base_attack_max"])
  print(heroes[hero]["base_str"])
  print(heroes[hero]["base_agi"])
  print(heroes[hero]["base_int"])
  print(heroes[hero]["str_gain"])
  print(heroes[hero]["agi_gain"])
  print(heroes[hero]["int_gain"])
  print(heroes[hero]["attack_range"])
  print(heroes[hero]["projectile_speed"])
  print(heroes[hero]["attack_rate"])
  print(heroes[hero]["move_speed"])
  print(heroes[hero]["turn_rate"])
  print(heroes[hero]["cm_enabled"])
  print("\n")
# Out:
# 1
# npc_dota_hero_antimage
# agi
# Melee
# ['Carry', 'Escape', 'Nuker']
# /apps/dota2/images/dota_react/heroes/antimage.png?
# /apps/dota2/images/dota_react/heroes/icons/antimage.png?
# 200
# 0.25
# 75
# 0
# 0
# 25
# 29
# 33
# 21
# 24
# 12
# 1.6
# 2.8
# 1.8
# 150
# 0
# 1.4
# 310
# None
# True
#
#
# 2
# npc_dota_hero_axe
# str
# Melee
# ['Initiator', 'Durable', 'Disabler', 'Jungler', 'Carry']
# /apps/dota2/images/dota_react/heroes/axe.png?
# /apps/dota2/images/dota_react/heroes/icons/axe.png?
# 200
# 2.75
# 75
# 0
# -1
# 25
# 27
# 31
# 25
# 20
# 18
# 3.4
# 2.2
# 1.6
# 150
# 900
# 1.7
# 310
# None
# True
#
#
# 3
# npc_dota_hero_bane
# int
# Ranged
# ['Support', 'Disabler', 'Nuker', 'Durable']
# /apps/dota2/images/dota_react/heroes/bane.png?
# /apps/dota2/images/dota_react/heroes/icons/bane.png?
# 200
# 0.25
# 75
# 0
# 1
# 25
# 33
# 39
# 22
# 22
# 22
# 2.5
# 2.5
# 2.5
# 400
# 900
# 1.7
# 305
# None
# True
#
#
# 4
# npc_dota_hero_bloodseeker
# agi
# Melee
# ...

# %% [markdown]
# ---

# %% [markdown]
# **REFERENCES:**
# [TypeError: list indices must be integers, not dict](https://stackoverflow.com/questions/26266425/typeerror-list-indices-must-be-integers-not-dict)

# %% [markdown]
# **Rodrigo Leite -** *drigols*
